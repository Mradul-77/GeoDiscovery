# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("food_coded.csv")
df.shape
# Out:
# (125, 61)

# %%
df.head(63)
# Out:
#           GPA  Gender  breakfast  calories_chicken  calories_day  \
# 0         2.4       2          1               430           NaN
# 1       3.654       1          1               610           3.0
# 2         3.3       1          1               720           4.0
# 3         3.2       1          1               430           3.0
# 4         3.5       1          1               720           2.0
# ..        ...     ...        ...               ...           ...
# 58        3.5       1          1               610           3.0
# 59        3.7       1          1               610           NaN
# 60        3.6       1          1               610           4.0
# 61  Personal        1          1               610           2.0
# 62        3.9       2          1               610           4.0
#
#     calories_scone  coffee                                       comfort_food  \
# 0            315.0       1                                               none
# ...

# %%
df.tail(62)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 63     2.6       1          1               610           4.0           980.0
# 64     3.5       1          1               610           3.0           420.0
# 65     3.2       1          1               610           NaN           315.0
# 66       3       1          1               720           3.0           420.0
# 67     3.6       1          1               610           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...
